# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import mne
import re
import mne
import pandas as pd
import glob
from datetime import datetime
import os

# %%
df1 = pd.read_pickle('seizure_data.pkl')
df2 = pd.read_pickle('seizure_data_2.pkl')
df3 = pd.read_pickle('seizure_data_3.pkl')

# %%
combined_df = pd.concat([df1, df2, df3], axis=0).reset_index(drop=True)

# %%
combined_df.to_pickle('siena_seizure_data.pkl')

# %%
combined_df
# Out:
#                                                   EEG Seizure Type  \
# 0            EEG Fp1  EEG F3  EEG C3  EEG P3  EEG ...          IAS
# 1            EEG Fp1  EEG F3   EEG C3   EEG P3   E...          IAS
# 2            EEG Fp1  EEG F3  EEG C3   EEG P3  EEG...          IAS
# 3            EEG Fp1  EEG F3  EEG C3  EEG P3  EEG ...          IAS
# 4            EEG Fp1  EEG F3  EEG C3  EEG P3   EEG...          IAS
# 5            EEG Fp1  EEG F3  EEG C3  EEG P3   EEG...          IAS
# 6            EEG Fp1  EEG F3  EEG C3  EEG P3  EEG ...          IAS
# 7            EEG Fp1  EEG F3  EEG C3  EEG P3  EEG ...          IAS
# 8            EEG Fp1  EEG F3  EEG C3  EEG P3  EEG ...          IAS
# 9            EEG Fp1  EEG F3  EEG C3  EEG P3  EEG ...          IAS
# 10           EEG Fp1  EEG F3  EEG C3  EEG P3  EEG ...          IAS
# 11           EEG Fp1  EEG F3  EEG C3  EEG P3  EEG ...          IAS
# 12           EEG Fp1  EEG F3  EEG C3  EEG P3  EEG ...          IAS
# ...
